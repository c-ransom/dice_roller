# %%
dice = input("Please type in the number of rolls and the number of sides of your dice: ")
dice
# Out:
# Please type in the number of rolls and the number of sides of your dice:  10d6
# '10d6'

# %%
import random

i=1

sample_space = []
while i <= int(n):
    sample_space.append(i)
    i+=1
print(sample_space)

i=1
rolls = []
while i <= int(r):
    rolls.append(random.choice(sample_space))
    i+=1
rolls
# Out:
# [1, 2, 3, 4, 5, 6]
# [2, 2, 1, 4, 6, 5, 5, 2, 4, 6]
